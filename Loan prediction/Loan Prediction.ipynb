# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('loan_train.csv')
test = pd.read_csv('loan_test.csv')
train.apply(lambda x: sum(x.isnull()))
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train.Gender = train.Gender.fillna('Unknown')
test.Gender = test.Gender.fillna('Unknown')

# %%
train.Married = train.Married.fillna('Unknown')
test.Married = test.Married.fillna('Unknown')

# %%
replace_dep = {'1':1, '2':2, '3+':3}
train.Dependents = train.Dependents.replace(replace_dep)
test.Dependents = test.Dependents.replace(replace_dep)

train.Dependents = train.Dependents.fillna('Unknown')
test.Dependents = test.Dependents.fillna('Unknown')

# %%
train.apply(lambda x: sum(x.isnull()))
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train.Self_Employed = train.Self_Employed.fillna('Unknown')
test.Self_Employed = test.Self_Employed.fillna('Unknown')

# %%
train.LoanAmount = train.LoanAmount.transform(lambda x: x.fillna(x.mean()))
test.LoanAmount = test.LoanAmount.transform(lambda x: x.fillna(x.mean()))

# %%
train.Loan_Amount_Term = train.Loan_Amount_Term.transform(lambda x: x.fillna(x.mean()))
test.Loan_Amount_Term = test.Loan_Amount_Term.transform(lambda x: x.fillna(x.mean()))

# %%
replace_dict = {1.0:'Yes', 0.0:'No'}

train.Credit_History = train.Credit_History.replace(replace_dict)
test.Credit_History = test.Credit_History.replace(replace_dict)
train.Credit_History = train.Credit_History.fillna('Unknown')
test.Credit_History = test.Credit_History.fillna('Unknown')

# %%
train
# Out:
#       Loan_ID   Gender Married Dependents     Education Self_Employed  \
# 0    LP001002     Male      No          0      Graduate            No
# 1    LP001003     Male     Yes          1      Graduate            No
# 2    LP001005     Male     Yes          0      Graduate           Yes
# 3    LP001006     Male     Yes          0  Not Graduate            No
# 4    LP001008     Male      No          0      Graduate            No
# 5    LP001011     Male     Yes          2      Graduate           Yes
# 6    LP001013     Male     Yes          0  Not Graduate            No
# 7    LP001014     Male     Yes          3      Graduate            No
# 8    LP001018     Male     Yes          2      Graduate            No
# 9    LP001020     Male     Yes          1      Graduate            No
# 10   LP001024     Male     Yes          2      Graduate            No
# 11   LP001027     Male     Yes          2      Graduate       Unknown
# ...

# %%
replace_marr = {'No':0,'Yes':1, 'Unknown':2}
train.Married = train.Married.replace(replace_marr)
test.Married = test.Married.replace(replace_marr)

# %%
replace_emp = {'No':0,'Yes':1, 'Unknown':2}
train.Self_Employed = train.Self_Employed.replace(replace_emp)
test.Self_Employed = test.Self_Employed.replace(replace_emp)

# %%
replace_edu = {'Not Graduate':0,'Graduate':1, 'Unknown':2}
train.Education = train.Education.replace(replace_edu)
test.Education = test.Education.replace(replace_edu)

# %%
replace = {'Unknown':0}
train.Dependents = train.Dependents.replace(replace)
test.Dependents = test.Dependents.replace(replace)

# %%
replace_cred = {'No':0,'Yes':1, 'Unknown':2}
train.Credit_History = train.Credit_History.replace(replace_cred)
test.Credit_History = test.Credit_History.replace(replace_cred)

# %%
replace_area = {'Rural':0,'Semiurban':1, 'Urban':2}
train.Property_Area = train.Property_Area.replace(replace_area)
test.Property_Area = test.Property_Area.replace(replace_area)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train['Loan_Status'] = le.fit_transform(train['Loan_Status'])

# %%
X = train.drop(['Loan_Status'], axis=1)
X = X.drop(['Loan_ID'], axis=1)

# %%
test1 = test.drop(['Loan_ID'], axis=1)
y = train.Loan_Status
X = X[['Credit_History','Education','Married','Self_Employed','Property_Area']]
test1 = test1[['Credit_History','Education','Married','Self_Employed','Property_Area']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_eval, y_train, y_eval = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
sc.fit(X_train)
# Out:
# /home/prathamesh/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, object were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train_std = sc.transform(X_train)
X_eval_std = sc.transform(X_eval)
# Out:
# /home/prathamesh/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64, object were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.
# /home/prathamesh/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64, object were all converted to float64 by StandardScaler.

# %%
#from sklearn import tree
#model = tree.DecisionTreeClassifier(criterion='gini')
#model.fit(X_train_std, y_train)
#y_pred = model.predict(X_eval_std)
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train_std, y_train)
y_pred = logreg.predict(X_eval_std)
# Out:
# /home/prathamesh/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_eval, y_pred))
# Out:
# 0.8292682926829268

# %%
loadId = test['Loan_ID']

# %%
sc.fit(test1)
# Out:
# /home/prathamesh/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, object were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
test1_std = sc.transform(test1)
# Out:
# /home/prathamesh/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64, object were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.

# %%
result = model.predict(test1_std)

# %%
result = pd.DataFrame(result)

# %%
submission = pd.concat([loadId, result], axis=1)
submission.columns.values[1]='Loan_Status'

# %%
submission
# Out:
#       Loan_ID  Loan_Status
# 0    LP001015            1
# 1    LP001022            1
# 2    LP001031            1
# 3    LP001035            1
# 4    LP001051            0
# 5    LP001054            1
# 6    LP001055            1
# 7    LP001056            0
# 8    LP001059            1
# 9    LP001067            1
# 10   LP001078            0
# 11   LP001082            1
# 12   LP001083            1
# 13   LP001094            0
# 14   LP001096            1
# 15   LP001099            1
# 16   LP001105            1
# 17   LP001107            1
# 18   LP001108            1
# 19   LP001115            1
# 20   LP001121            1
# 21   LP001124            0
# 22   LP001128            1
# 23   LP001135            0
# 24   LP001149            1
# 25   LP001153            0
# 26   LP001163            1
# 27   LP001169            1
# 28   LP001174            1
# 29   LP001176            1
# ..        ...          ...
# 337  LP002856            1
# 338  LP002857            1
# ...
